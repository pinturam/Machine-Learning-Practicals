# %% [markdown]
# # Data Wrangling

# %% [markdown]
# **About the notebook:** In this notebook, I have covered some important aspects of data wrangling these concepts certainly making me to wrangle the data from any ways.

# %% [markdown]
# **Author:** *Pintu Ram*

# %% [markdown]
# **About Data Wrangling:** Data wrangling is a broad term used to describe the process of transforming raw data to a clean and organized formate ready for use data.

# %% [markdown]
# ###  List of Operations Performed

# %% [markdown]
# 1. Creating a Data Frame
# 2. Describing the Data
# 3. Navigating DataFrames
# 4. Selecting Rows Based on Conditionals
# 5. Replacing Values
# 6. Renaming Columns
# 7. Finding the Minimum, Maximum, Sum, Average, and Count
# 8. Finding Unique Values
# 9. Handling Missing Values
# 10. Deleting a Column
# 11. Deleting a Row
# 12. Dropping Duplicate Rows
# 13. Grouping Rows by Values
# 14. Grouping Rows by Time
# 15. Looping Over a Column
# 16. Applying a Function Over All Elements in a Column
# 17. Applying a Function to Groups
# 18. Concatenating DataFrames
# 19. Merging DataFrames

# %% [markdown]
# ### 1. Creating dataframe

# %%
# laod library
import pandas as pd

# %%
# create dataframe
dataframe = pd.DataFrame()

# %%
#print dataframe
dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# add columns
dataframe['name'] = ['pintu', 'ram']
dataframe['age'] = [20,21]
dataframe['student']= [True, False]

# %%
# show dataframe
dataframe
# Out:
#     name  age  student
# 0  pintu   20     True
# 1    ram   21    False

# %%
# create row
new_row = pd.Series(['pappu', 22, True], index = ['name', 'age', 'student'])

# %%
# append row
dataframe.append(new_row, ignore_index= True)
# Out:
#     name  age  student
# 0  pintu   20     True
# 1    ram   21    False
# 2  pappu   22     True

# %% [markdown]
# ### 2. Describing the data

# %%
# select first two rows
dataframe.head(2)
# Out:
#     name  age  student
# 0  pintu   20     True
# 1    ram   21    False

# %%
# show dimensions
dataframe.shape
# Out:
# (2, 3)

# %%
# show statistics
dataframe.describe()
# Out:
#              age
# count   2.000000
# mean   20.500000
# std     0.707107
# min    20.000000
# 25%    20.250000
# 50%    20.500000
# 75%    20.750000
# max    21.000000

# %% [markdown]
# ### 3. Navigating Dataframes

# %%
# load library
import pandas as pd

# %%
# load data
df = pd.read_csv('Q:/Detasets/titanic.csv')

# %%
# select first row
df.iloc[0]
# Out:
# pclass                                   1
# survived                                 1
# name         Allen, Miss. Elisabeth Walton
# sex                                 female
# age                                     29
# sibsp                                    0
# parch                                    0
# ticket                               24160
# fare                               211.338
# cabin                                   B5
# embarked                                 S
# boat                                     2
# body                                   NaN
# home.dest                     St Louis, MO
# Name: 0, dtype: object

# %%
# select first two rows
df.iloc[0:1]
# Out:
#    pclass  survived                           name     sex   age  sibsp  \
# 0     1.0       1.0  Allen, Miss. Elisabeth Walton  female  29.0    0.0
#
#    parch ticket      fare cabin embarked boat  body     home.dest
# 0    0.0  24160  211.3375    B5        S    2   NaN  St Louis, MO

# %%
# select first four rows
df.iloc[0:4]
# Out:
#    pclass  survived                                  name     sex      age  \
# 0     1.0       1.0         Allen, Miss. Elisabeth Walton  female  29.0000
# 1     1.0       1.0        Allison, Master. Hudson Trevor    male   0.9167
# 2     1.0       0.0          Allison, Miss. Helen Loraine  female   2.0000
# 3     1.0       0.0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
# set index
df = df.set_index(df['name']) # by default indexes are integer, we set here as string (name)

# %%
# show row
df.loc['Allen, Miss. Elisabeth Walton'] # returns by name as index
# Out:
# pclass                                   1
# survived                                 1
# name         Allen, Miss. Elisabeth Walton
# sex                                 female
# age                                     29
# sibsp                                    0
# parch                                    0
# ticket                               24160
# fare                               211.338
# cabin                                   B5
# embarked                                 S
# boat                                     2
# body                                   NaN
# home.dest                     St Louis, MO
# Name: Allen, Miss. Elisabeth Walton, dtype: object

# %%
# show first index
df.iloc[0] # returns first row regardless of whether index is an interger or a label
# Out:
# pclass                                   1
# survived                                 1
# name         Allen, Miss. Elisabeth Walton
# sex                                 female
# age                                     29
# sibsp                                    0
# parch                                    0
# ticket                               24160
# fare                               211.338
# cabin                                   B5
# embarked                                 S
# boat                                     2
# body                                   NaN
# home.dest                     St Louis, MO
# Name: Allen, Miss. Elisabeth Walton, dtype: object

# %% [markdown]
# ### 4. Selecting rows based on conditinals

# %%
df
# Out:
#                                                  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                       1.0       1.0
# Allison, Master. Hudson Trevor                      1.0       1.0
# Allison, Miss. Helen Loraine                        1.0       0.0
# Allison, Mr. Hudson Joshua Creighton                1.0       0.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0       0.0
# ...                                                 ...       ...
# Zabour, Miss. Thamine                               3.0       0.0
# Zakarian, Mr. Mapriededer                           3.0       0.0
# Zakarian, Mr. Ortin                                 3.0       0.0
# Zimmerman, Mr. Leo                                  3.0       0.0
# NaN                                                 NaN       NaN
#
#                                                                                             name  \
# name
# Allen, Miss. Elisabeth Walton                                      Allen, Miss. Elisabeth Walton
# Allison, Master. Hudson Trevor                                    Allison, Master. Hudson Trevor
# Allison, Miss. Helen Loraine                                        Allison, Miss. Helen Loraine
# Allison, Mr. Hudson Joshua Creighton                        Allison, Mr. Hudson Joshua Creighton
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...                                                                                          ...
# Zabour, Miss. Thamine                                                      Zabour, Miss. Thamine
# Zakarian, Mr. Mapriededer                                              Zakarian, Mr. Mapriededer
# Zakarian, Mr. Ortin                                                          Zakarian, Mr. Ortin
# Zimmerman, Mr. Leo                                                            Zimmerman, Mr. Leo
# NaN                                                                                          NaN
#
#                                                     sex      age  sibsp  \
# name
# Allen, Miss. Elisabeth Walton                    female  29.0000    0.0
# Allison, Master. Hudson Trevor                     male   0.9167    1.0
# Allison, Miss. Helen Loraine                     female   2.0000    1.0
# Allison, Mr. Hudson Joshua Creighton               male  30.0000    1.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
# ...                                                 ...      ...    ...
# Zabour, Miss. Thamine                            female      NaN    1.0
# Zakarian, Mr. Mapriededer                          male  26.5000    0.0
# Zakarian, Mr. Ortin                                male  27.0000    0.0
# Zimmerman, Mr. Leo                                 male  29.0000    0.0
# NaN                                                 NaN      NaN    NaN
#
#                                                  parch  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton                      0.0   24160  211.3375
# Allison, Master. Hudson Trevor                     2.0  113781  151.5500
# Allison, Miss. Helen Loraine                       2.0  113781  151.5500
# Allison, Mr. Hudson Joshua Creighton               2.0  113781  151.5500
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    2.0  113781  151.5500
# ...                                                ...     ...       ...
# Zabour, Miss. Thamine                              0.0    2665   14.4542
# Zakarian, Mr. Mapriededer                          0.0    2656    7.2250
# Zakarian, Mr. Ortin                                0.0    2670    7.2250
# Zimmerman, Mr. Leo                                 0.0  315082    7.8750
# NaN                                                NaN     NaN       NaN
#
#                                                    cabin embarked boat   body  \
# name
# Allen, Miss. Elisabeth Walton                         B5        S    2    NaN
# Allison, Master. Hudson Trevor                   C22 C26        S   11    NaN
# Allison, Miss. Helen Loraine                     C22 C26        S  NaN    NaN
# Allison, Mr. Hudson Joshua Creighton             C22 C26        S  NaN  135.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  C22 C26        S  NaN    NaN
# ...                                                  ...      ...  ...    ...
# Zabour, Miss. Thamine                                NaN        C  NaN    NaN
# Zakarian, Mr. Mapriededer                            NaN        C  NaN  304.0
# Zakarian, Mr. Ortin                                  NaN        C  NaN    NaN
# Zimmerman, Mr. Leo                                   NaN        S  NaN    NaN
# NaN                                                  NaN      NaN  NaN    NaN
#
#                                                                        home.dest
# name
# Allen, Miss. Elisabeth Walton                                       St Louis, MO
# Allison, Master. Hudson Trevor                   Montreal, PQ / Chesterville, ON
# Allison, Miss. Helen Loraine                     Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton             Montreal, PQ / Chesterville, ON
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Montreal, PQ / Chesterville, ON
# ...                                                                          ...
# Zabour, Miss. Thamine                                                        NaN
# Zakarian, Mr. Mapriededer                                                    NaN
# Zakarian, Mr. Ortin                                                          NaN
# Zimmerman, Mr. Leo                                                           NaN
# NaN                                                                          NaN
#
# [1310 rows x 14 columns]

# %%
# show top two rows where column 'sex' is female (single row selection)
df[df['sex']=='female'].head(2)
# Out:
#                                pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton     1.0       1.0
# Allison, Miss. Helen Loraine      1.0       0.0
#
#                                                         name     sex   age  \
# name
# Allen, Miss. Elisabeth Walton  Allen, Miss. Elisabeth Walton  female  29.0
# Allison, Miss. Helen Loraine    Allison, Miss. Helen Loraine  female   2.0
#
#                                sibsp  parch  ticket      fare    cabin  \
# name
# Allen, Miss. Elisabeth Walton    0.0    0.0   24160  211.3375       B5
# Allison, Miss. Helen Loraine     1.0    2.0  113781  151.5500  C22 C26
#
#                               embarked boat  body  \
# name
# Allen, Miss. Elisabeth Walton        S    2   NaN
# Allison, Miss. Helen Loraine         S  NaN   NaN
#
#                                                      home.dest
# name
# Allen, Miss. Elisabeth Walton                     St Louis, MO
# Allison, Miss. Helen Loraine   Montreal, PQ / Chesterville, ON

# %%
# multiples row selection
df[(df['sex']=='female') & (df['age']>=65)]
# Out:
#                                                     pclass  survived  \
# name
# Cavendish, Mrs. Tyrell William (Julia Florence ...     1.0       1.0
#
#                                                                                                  name  \
# name
# Cavendish, Mrs. Tyrell William (Julia Florence ...  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#                                                        sex   age  sibsp  \
# name
# Cavendish, Mrs. Tyrell William (Julia Florence ...  female  76.0    1.0
#
#                                                     parch ticket   fare cabin  \
# name
# Cavendish, Mrs. Tyrell William (Julia Florence ...    0.0  19877  78.85   C46
#
#                                                    embarked boat  body  \
# name
# Cavendish, Mrs. Tyrell William (Julia Florence ...        S    6   NaN
#
#                                                                   home.dest
# name
# Cavendish, Mrs. Tyrell William (Julia Florence ...  Little Onn Hall, Staffs

# %% [markdown]
# ###  5.Replacing values

# %%
# replace female as woman
df['sex'].replace('female', 'woman').head(2)
# Out:
# name
# Allen, Miss. Elisabeth Walton     woman
# Allison, Master. Hudson Trevor     male
# Name: sex, dtype: object

# %%
# replace female as woman and male as man
df['sex'].replace(['female', 'male'], ['woman', 'man']).head(2)
# Out:
# name
# Allen, Miss. Elisabeth Walton     woman
# Allison, Master. Hudson Trevor      man
# Name: sex, dtype: object

# %%
# view dataframe
df.head(1)
# Out:
#                                pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton     1.0       1.0
#
#                                                         name     sex   age  \
# name
# Allen, Miss. Elisabeth Walton  Allen, Miss. Elisabeth Walton  female  29.0
#
#                                sibsp  parch ticket      fare cabin embarked  \
# name
# Allen, Miss. Elisabeth Walton    0.0    0.0  24160  211.3375    B5        S
#
#                               boat  body     home.dest
# name
# Allen, Miss. Elisabeth Walton    2   NaN  St Louis, MO

# %%
# replacing for entire dataframe
df.replace(['female', 'male'], ['woman', 'man'])
# Out:
#                                                  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                       1.0       1.0
# Allison, Master. Hudson Trevor                      1.0       1.0
# Allison, Miss. Helen Loraine                        1.0       0.0
# Allison, Mr. Hudson Joshua Creighton                1.0       0.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0       0.0
# ...                                                 ...       ...
# Zabour, Miss. Thamine                               3.0       0.0
# Zakarian, Mr. Mapriededer                           3.0       0.0
# Zakarian, Mr. Ortin                                 3.0       0.0
# Zimmerman, Mr. Leo                                  3.0       0.0
# NaN                                                 NaN       NaN
#
#                                                                                             name  \
# name
# Allen, Miss. Elisabeth Walton                                      Allen, Miss. Elisabeth Walton
# Allison, Master. Hudson Trevor                                    Allison, Master. Hudson Trevor
# Allison, Miss. Helen Loraine                                        Allison, Miss. Helen Loraine
# Allison, Mr. Hudson Joshua Creighton                        Allison, Mr. Hudson Joshua Creighton
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...                                                                                          ...
# Zabour, Miss. Thamine                                                      Zabour, Miss. Thamine
# Zakarian, Mr. Mapriededer                                              Zakarian, Mr. Mapriededer
# Zakarian, Mr. Ortin                                                          Zakarian, Mr. Ortin
# Zimmerman, Mr. Leo                                                            Zimmerman, Mr. Leo
# NaN                                                                                          NaN
#
#                                                    sex      age  sibsp  parch  \
# name
# Allen, Miss. Elisabeth Walton                    woman  29.0000    0.0    0.0
# Allison, Master. Hudson Trevor                     man   0.9167    1.0    2.0
# Allison, Miss. Helen Loraine                     woman   2.0000    1.0    2.0
# Allison, Mr. Hudson Joshua Creighton               man  30.0000    1.0    2.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  woman  25.0000    1.0    2.0
# ...                                                ...      ...    ...    ...
# Zabour, Miss. Thamine                            woman      NaN    1.0    0.0
# Zakarian, Mr. Mapriededer                          man  26.5000    0.0    0.0
# Zakarian, Mr. Ortin                                man  27.0000    0.0    0.0
# Zimmerman, Mr. Leo                                 man  29.0000    0.0    0.0
# NaN                                                NaN      NaN    NaN    NaN
#
#                                                  ticket      fare    cabin  \
# name
# Allen, Miss. Elisabeth Walton                     24160  211.3375       B5
# Allison, Master. Hudson Trevor                   113781  151.5500  C22 C26
# Allison, Miss. Helen Loraine                     113781  151.5500  C22 C26
# Allison, Mr. Hudson Joshua Creighton             113781  151.5500  C22 C26
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  113781  151.5500  C22 C26
# ...                                                 ...       ...      ...
# Zabour, Miss. Thamine                              2665   14.4542      NaN
# Zakarian, Mr. Mapriededer                          2656    7.2250      NaN
# Zakarian, Mr. Ortin                                2670    7.2250      NaN
# Zimmerman, Mr. Leo                               315082    7.8750      NaN
# NaN                                                 NaN       NaN      NaN
#
#                                                 embarked boat   body  \
# name
# Allen, Miss. Elisabeth Walton                          S    2    NaN
# Allison, Master. Hudson Trevor                         S   11    NaN
# Allison, Miss. Helen Loraine                           S  NaN    NaN
# Allison, Mr. Hudson Joshua Creighton                   S  NaN  135.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)        S  NaN    NaN
# ...                                                  ...  ...    ...
# Zabour, Miss. Thamine                                  C  NaN    NaN
# Zakarian, Mr. Mapriededer                              C  NaN  304.0
# Zakarian, Mr. Ortin                                    C  NaN    NaN
# Zimmerman, Mr. Leo                                     S  NaN    NaN
# NaN                                                  NaN  NaN    NaN
#
#                                                                        home.dest
# name
# Allen, Miss. Elisabeth Walton                                       St Louis, MO
# Allison, Master. Hudson Trevor                   Montreal, PQ / Chesterville, ON
# Allison, Miss. Helen Loraine                     Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton             Montreal, PQ / Chesterville, ON
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Montreal, PQ / Chesterville, ON
# ...                                                                          ...
# Zabour, Miss. Thamine                                                        NaN
# Zakarian, Mr. Mapriededer                                                    NaN
# Zakarian, Mr. Ortin                                                          NaN
# Zimmerman, Mr. Leo                                                           NaN
# NaN                                                                          NaN
#
# [1310 rows x 14 columns]

# %% [markdown]
# ### 6. Renaming columns names

# %%
df.rename(columns={'sex':'gender'})
# Out:
#                                                  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                       1.0       1.0
# Allison, Master. Hudson Trevor                      1.0       1.0
# Allison, Miss. Helen Loraine                        1.0       0.0
# Allison, Mr. Hudson Joshua Creighton                1.0       0.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0       0.0
# ...                                                 ...       ...
# Zabour, Miss. Thamine                               3.0       0.0
# Zakarian, Mr. Mapriededer                           3.0       0.0
# Zakarian, Mr. Ortin                                 3.0       0.0
# Zimmerman, Mr. Leo                                  3.0       0.0
# NaN                                                 NaN       NaN
#
#                                                                                             name  \
# name
# Allen, Miss. Elisabeth Walton                                      Allen, Miss. Elisabeth Walton
# Allison, Master. Hudson Trevor                                    Allison, Master. Hudson Trevor
# Allison, Miss. Helen Loraine                                        Allison, Miss. Helen Loraine
# Allison, Mr. Hudson Joshua Creighton                        Allison, Mr. Hudson Joshua Creighton
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...                                                                                          ...
# Zabour, Miss. Thamine                                                      Zabour, Miss. Thamine
# Zakarian, Mr. Mapriededer                                              Zakarian, Mr. Mapriededer
# Zakarian, Mr. Ortin                                                          Zakarian, Mr. Ortin
# Zimmerman, Mr. Leo                                                            Zimmerman, Mr. Leo
# NaN                                                                                          NaN
#
#                                                  gender      age  sibsp  \
# name
# Allen, Miss. Elisabeth Walton                    female  29.0000    0.0
# Allison, Master. Hudson Trevor                     male   0.9167    1.0
# Allison, Miss. Helen Loraine                     female   2.0000    1.0
# Allison, Mr. Hudson Joshua Creighton               male  30.0000    1.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
# ...                                                 ...      ...    ...
# Zabour, Miss. Thamine                            female      NaN    1.0
# Zakarian, Mr. Mapriededer                          male  26.5000    0.0
# Zakarian, Mr. Ortin                                male  27.0000    0.0
# Zimmerman, Mr. Leo                                 male  29.0000    0.0
# NaN                                                 NaN      NaN    NaN
#
#                                                  parch  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton                      0.0   24160  211.3375
# Allison, Master. Hudson Trevor                     2.0  113781  151.5500
# Allison, Miss. Helen Loraine                       2.0  113781  151.5500
# Allison, Mr. Hudson Joshua Creighton               2.0  113781  151.5500
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    2.0  113781  151.5500
# ...                                                ...     ...       ...
# Zabour, Miss. Thamine                              0.0    2665   14.4542
# Zakarian, Mr. Mapriededer                          0.0    2656    7.2250
# Zakarian, Mr. Ortin                                0.0    2670    7.2250
# Zimmerman, Mr. Leo                                 0.0  315082    7.8750
# NaN                                                NaN     NaN       NaN
#
#                                                    cabin embarked boat   body  \
# name
# Allen, Miss. Elisabeth Walton                         B5        S    2    NaN
# Allison, Master. Hudson Trevor                   C22 C26        S   11    NaN
# Allison, Miss. Helen Loraine                     C22 C26        S  NaN    NaN
# Allison, Mr. Hudson Joshua Creighton             C22 C26        S  NaN  135.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  C22 C26        S  NaN    NaN
# ...                                                  ...      ...  ...    ...
# Zabour, Miss. Thamine                                NaN        C  NaN    NaN
# Zakarian, Mr. Mapriededer                            NaN        C  NaN  304.0
# Zakarian, Mr. Ortin                                  NaN        C  NaN    NaN
# Zimmerman, Mr. Leo                                   NaN        S  NaN    NaN
# NaN                                                  NaN      NaN  NaN    NaN
#
#                                                                        home.dest
# name
# Allen, Miss. Elisabeth Walton                                       St Louis, MO
# Allison, Master. Hudson Trevor                   Montreal, PQ / Chesterville, ON
# Allison, Miss. Helen Loraine                     Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton             Montreal, PQ / Chesterville, ON
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Montreal, PQ / Chesterville, ON
# ...                                                                          ...
# Zabour, Miss. Thamine                                                        NaN
# Zakarian, Mr. Mapriededer                                                    NaN
# Zakarian, Mr. Ortin                                                          NaN
# Zimmerman, Mr. Leo                                                           NaN
# NaN                                                                          NaN
#
# [1310 rows x 14 columns]

# %% [markdown]
# ### 7.Find minimum, maximum, sum, average, count

# %%
df['age'].min()
# Out:
# 0.1667

# %%
df['age'].max()
# Out:
# 80.0

# %%
df['age'].sum()
# Out:
# 31255.6667

# %%
df['age'].count()
# Out:
# 1046

# %% [markdown]
# ### Find Statistics

# %%
df['age'].var() # variance
# Out:
# 207.74897359969756

# %%
df['age'].std() # standard deviation
# Out:
# 14.413499699923594

# %%
df['age'].skew # skewness
# Out:
# <bound method Series.skew of name
# Allen, Miss. Elisabeth Walton                      29.0000
# Allison, Master. Hudson Trevor                      0.9167
# Allison, Miss. Helen Loraine                        2.0000
# Allison, Mr. Hudson Joshua Creighton               30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    25.0000
#                                                     ...
# Zabour, Miss. Thamine                                  NaN
# Zakarian, Mr. Mapriededer                          26.5000
# Zakarian, Mr. Ortin                                27.0000
# Zimmerman, Mr. Leo                                 29.0000
# NaN                                                    NaN
# Name: age, Length: 1310, dtype: float64>

# %%
df['age'].sem()  # standard error of mean
# Out:
# 0.44565994375550755

# %%
df['age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
df['age'].median()
# Out:
# 28.0

# %% [markdown]
# ### 8. Finding unique values

# %%
df['age'].unique() # veiw an array of all unique values in a column
# Out:
# array([29.    ,  0.9167,  2.    , 30.    , 25.    , 48.    , 63.    ,
#        39.    , 53.    , 71.    , 47.    , 18.    , 24.    , 26.    ,
#        80.    ,     nan, 50.    , 32.    , 36.    , 37.    , 42.    ,
#        19.    , 35.    , 28.    , 45.    , 40.    , 58.    , 22.    ,
#        41.    , 44.    , 59.    , 60.    , 33.    , 17.    , 11.    ,
#        14.    , 49.    , 76.    , 46.    , 27.    , 64.    , 55.    ,
#        70.    , 38.    , 51.    , 31.    ,  4.    , 54.    , 23.    ,
#        43.    , 52.    , 16.    , 32.5   , 21.    , 15.    , 65.    ,
#        28.5   , 45.5   , 56.    , 13.    , 61.    , 34.    ,  6.    ,
#        57.    , 62.    , 67.    ,  1.    , 12.    , 20.    ,  0.8333,
#         8.    ,  0.6667,  7.    ,  3.    , 36.5   , 18.5   ,  5.    ,
#        66.    ,  9.    ,  0.75  , 70.5   , 22.5   ,  0.3333,  0.1667,
#        40.5   , 10.    , 23.5   , 34.5   , 20.5   , 30.5   , 55.5   ,
#        38.5   , 14.5   , 24.5   , 60.5   , 74.    ,  0.4167, 11.5   ,
#        26.5   ])

# %%
df['age'].value_counts() # displays all unique values with no. of times each values appears
# Out:
# 24.0000    47
# 22.0000    43
# 21.0000    41
# 30.0000    40
# 18.0000    39
#            ..
# 26.5000     1
# 67.0000     1
# 70.5000     1
# 76.0000     1
# 0.6667      1
# Name: age, Length: 98, dtype: int64

# %%
df['age'].nunique() # finds total no. of unique values
# Out:
# 98

# %% [markdown]
# ### 9.Handling Missing Values

# %%
df.isnull().sum() # returns null values content
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
df.notnull().sum() # return not null values contents
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
# Replace values with NaN
import numpy as np
df['sex'] = df['sex'].replace('male', np.nan)

# %%
df.head(2)
# Out:
#                                 pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton      1.0       1.0
# Allison, Master. Hudson Trevor     1.0       1.0
#
#                                                           name     sex  \
# name
# Allen, Miss. Elisabeth Walton    Allen, Miss. Elisabeth Walton  female
# Allison, Master. Hudson Trevor  Allison, Master. Hudson Trevor     NaN
#
#                                     age  sibsp  parch  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton   29.0000    0.0    0.0   24160  211.3375
# Allison, Master. Hudson Trevor   0.9167    1.0    2.0  113781  151.5500
#
#                                   cabin embarked boat  body  \
# name
# Allen, Miss. Elisabeth Walton        B5        S    2   NaN
# Allison, Master. Hudson Trevor  C22 C26        S   11   NaN
#
#                                                       home.dest
# name
# Allen, Miss. Elisabeth Walton                      St Louis, MO
# Allison, Master. Hudson Trevor  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### 10. Delete a column

# %%
# a single column
df.drop('age', axis=1).head(2)
# Out:
#                                 pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton      1.0       1.0
# Allison, Master. Hudson Trevor     1.0       1.0
#
#                                                           name     sex  sibsp  \
# name
# Allen, Miss. Elisabeth Walton    Allen, Miss. Elisabeth Walton  female    0.0
# Allison, Master. Hudson Trevor  Allison, Master. Hudson Trevor     NaN    1.0
#
#                                 parch  ticket      fare    cabin embarked  \
# name
# Allen, Miss. Elisabeth Walton     0.0   24160  211.3375       B5        S
# Allison, Master. Hudson Trevor    2.0  113781  151.5500  C22 C26        S
#
#                                boat  body                        home.dest
# name
# Allen, Miss. Elisabeth Walton     2   NaN                     St Louis, MO
# Allison, Master. Hudson Trevor   11   NaN  Montreal, PQ / Chesterville, ON

# %%
# multiple column
df.drop(['body','ticket'], axis=1).head(2)
# Out:
#                                 pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton      1.0       1.0
# Allison, Master. Hudson Trevor     1.0       1.0
#
#                                                           name     sex  \
# name
# Allen, Miss. Elisabeth Walton    Allen, Miss. Elisabeth Walton  female
# Allison, Master. Hudson Trevor  Allison, Master. Hudson Trevor     NaN
#
#                                     age  sibsp  parch      fare    cabin  \
# name
# Allen, Miss. Elisabeth Walton   29.0000    0.0    0.0  211.3375       B5
# Allison, Master. Hudson Trevor   0.9167    1.0    2.0  151.5500  C22 C26
#
#                                embarked boat                        home.dest
# name
# Allen, Miss. Elisabeth Walton         S    2                     St Louis, MO
# Allison, Master. Hudson Trevor        S   11  Montreal, PQ / Chesterville, ON

# %%
# delete by column index
df.drop(df.columns[0], axis=1).head(2)
# Out:
#                                 survived                            name  \
# name
# Allen, Miss. Elisabeth Walton        1.0   Allen, Miss. Elisabeth Walton
# Allison, Master. Hudson Trevor       1.0  Allison, Master. Hudson Trevor
#
#                                    sex      age  sibsp  parch  ticket  \
# name
# Allen, Miss. Elisabeth Walton   female  29.0000    0.0    0.0   24160
# Allison, Master. Hudson Trevor     NaN   0.9167    1.0    2.0  113781
#
#                                     fare    cabin embarked boat  body  \
# name
# Allen, Miss. Elisabeth Walton   211.3375       B5        S    2   NaN
# Allison, Master. Hudson Trevor  151.5500  C22 C26        S   11   NaN
#
#                                                       home.dest
# name
# Allen, Miss. Elisabeth Walton                      St Louis, MO
# Allison, Master. Hudson Trevor  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### 11.Deleting Rows

# %%
df[df['sex']!='female']  # conditional method
# Out:
#                                       pclass  survived  \
# name
# Allison, Master. Hudson Trevor           1.0       1.0
# Allison, Mr. Hudson Joshua Creighton     1.0       0.0
# Anderson, Mr. Harry                      1.0       1.0
# Andrews, Mr. Thomas Jr                   1.0       0.0
# Artagaveytia, Mr. Ramon                  1.0       0.0
# ...                                      ...       ...
# Yousseff, Mr. Gerious                    3.0       0.0
# Zakarian, Mr. Mapriededer                3.0       0.0
# Zakarian, Mr. Ortin                      3.0       0.0
# Zimmerman, Mr. Leo                       3.0       0.0
# NaN                                      NaN       NaN
#
#                                                                       name  \
# name
# Allison, Master. Hudson Trevor              Allison, Master. Hudson Trevor
# Allison, Mr. Hudson Joshua Creighton  Allison, Mr. Hudson Joshua Creighton
# Anderson, Mr. Harry                                    Anderson, Mr. Harry
# Andrews, Mr. Thomas Jr                              Andrews, Mr. Thomas Jr
# Artagaveytia, Mr. Ramon                            Artagaveytia, Mr. Ramon
# ...                                                                    ...
# Yousseff, Mr. Gerious                                Yousseff, Mr. Gerious
# Zakarian, Mr. Mapriededer                        Zakarian, Mr. Mapriededer
# Zakarian, Mr. Ortin                                    Zakarian, Mr. Ortin
# Zimmerman, Mr. Leo                                      Zimmerman, Mr. Leo
# NaN                                                                    NaN
#
#                                       sex      age  sibsp  parch    ticket  \
# name
# Allison, Master. Hudson Trevor        NaN   0.9167    1.0    2.0    113781
# Allison, Mr. Hudson Joshua Creighton  NaN  30.0000    1.0    2.0    113781
# Anderson, Mr. Harry                   NaN  48.0000    0.0    0.0     19952
# Andrews, Mr. Thomas Jr                NaN  39.0000    0.0    0.0    112050
# Artagaveytia, Mr. Ramon               NaN  71.0000    0.0    0.0  PC 17609
# ...                                   ...      ...    ...    ...       ...
# Yousseff, Mr. Gerious                 NaN      NaN    0.0    0.0      2627
# Zakarian, Mr. Mapriededer             NaN  26.5000    0.0    0.0      2656
# Zakarian, Mr. Ortin                   NaN  27.0000    0.0    0.0      2670
# Zimmerman, Mr. Leo                    NaN  29.0000    0.0    0.0    315082
# NaN                                   NaN      NaN    NaN    NaN       NaN
#
#                                           fare    cabin embarked boat   body  \
# name
# Allison, Master. Hudson Trevor        151.5500  C22 C26        S   11    NaN
# Allison, Mr. Hudson Joshua Creighton  151.5500  C22 C26        S  NaN  135.0
# Anderson, Mr. Harry                    26.5500      E12        S    3    NaN
# Andrews, Mr. Thomas Jr                  0.0000      A36        S  NaN    NaN
# Artagaveytia, Mr. Ramon                49.5042      NaN        C  NaN   22.0
# ...                                        ...      ...      ...  ...    ...
# Yousseff, Mr. Gerious                  14.4583      NaN        C  NaN    NaN
# Zakarian, Mr. Mapriededer               7.2250      NaN        C  NaN  304.0
# Zakarian, Mr. Ortin                     7.2250      NaN        C  NaN    NaN
# Zimmerman, Mr. Leo                      7.8750      NaN        S  NaN    NaN
# NaN                                        NaN      NaN      NaN  NaN    NaN
#
#                                                             home.dest
# name
# Allison, Master. Hudson Trevor        Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton  Montreal, PQ / Chesterville, ON
# Anderson, Mr. Harry                                      New York, NY
# Andrews, Mr. Thomas Jr                                    Belfast, NI
# Artagaveytia, Mr. Ramon                           Montevideo, Uruguay
# ...                                                               ...
# Yousseff, Mr. Gerious                                             NaN
# Zakarian, Mr. Mapriededer                                         NaN
# Zakarian, Mr. Ortin                                               NaN
# Zimmerman, Mr. Leo                                                NaN
# NaN                                                               NaN
#
# [844 rows x 14 columns]

# %%
df.head(2)
# Out:
#                                 pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton      1.0       1.0
# Allison, Master. Hudson Trevor     1.0       1.0
#
#                                                           name     sex  \
# name
# Allen, Miss. Elisabeth Walton    Allen, Miss. Elisabeth Walton  female
# Allison, Master. Hudson Trevor  Allison, Master. Hudson Trevor     NaN
#
#                                     age  sibsp  parch  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton   29.0000    0.0    0.0   24160  211.3375
# Allison, Master. Hudson Trevor   0.9167    1.0    2.0  113781  151.5500
#
#                                   cabin embarked boat  body  \
# name
# Allen, Miss. Elisabeth Walton        B5        S    2   NaN
# Allison, Master. Hudson Trevor  C22 C26        S   11   NaN
#
#                                                       home.dest
# name
# Allen, Miss. Elisabeth Walton                      St Louis, MO
# Allison, Master. Hudson Trevor  Montreal, PQ / Chesterville, ON

# %%
df.drop(['Allen, Miss. Elisabeth Walton']).head(2) # delete first two rows
# Out:
#                                 pclass  survived  \
# name
# Allison, Master. Hudson Trevor     1.0       1.0
# Allison, Miss. Helen Loraine       1.0       0.0
#
#                                                           name     sex  \
# name
# Allison, Master. Hudson Trevor  Allison, Master. Hudson Trevor     NaN
# Allison, Miss. Helen Loraine      Allison, Miss. Helen Loraine  female
#
#                                    age  sibsp  parch  ticket    fare    cabin  \
# name
# Allison, Master. Hudson Trevor  0.9167    1.0    2.0  113781  151.55  C22 C26
# Allison, Miss. Helen Loraine    2.0000    1.0    2.0  113781  151.55  C22 C26
#
#                                embarked boat  body  \
# name
# Allison, Master. Hudson Trevor        S   11   NaN
# Allison, Miss. Helen Loraine          S  NaN   NaN
#
#                                                       home.dest
# name
# Allison, Master. Hudson Trevor  Montreal, PQ / Chesterville, ON
# Allison, Miss. Helen Loraine    Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### 12. Dropping duplicate rows

# %%
df.drop_duplicates().head()
# Out:
#                                                  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                       1.0       1.0
# Allison, Master. Hudson Trevor                      1.0       1.0
# Allison, Miss. Helen Loraine                        1.0       0.0
# Allison, Mr. Hudson Joshua Creighton                1.0       0.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0       0.0
#
#                                                                                             name  \
# name
# Allen, Miss. Elisabeth Walton                                      Allen, Miss. Elisabeth Walton
# Allison, Master. Hudson Trevor                                    Allison, Master. Hudson Trevor
# Allison, Miss. Helen Loraine                                        Allison, Miss. Helen Loraine
# Allison, Mr. Hudson Joshua Creighton                        Allison, Mr. Hudson Joshua Creighton
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#                                                     sex      age  sibsp  \
# name
# Allen, Miss. Elisabeth Walton                    female  29.0000    0.0
# Allison, Master. Hudson Trevor                      NaN   0.9167    1.0
# Allison, Miss. Helen Loraine                     female   2.0000    1.0
# Allison, Mr. Hudson Joshua Creighton                NaN  30.0000    1.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
#
#                                                  parch  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton                      0.0   24160  211.3375
# Allison, Master. Hudson Trevor                     2.0  113781  151.5500
# Allison, Miss. Helen Loraine                       2.0  113781  151.5500
# Allison, Mr. Hudson Joshua Creighton               2.0  113781  151.5500
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    2.0  113781  151.5500
#
#                                                    cabin embarked boat   body  \
# name
# Allen, Miss. Elisabeth Walton                         B5        S    2    NaN
# Allison, Master. Hudson Trevor                   C22 C26        S   11    NaN
# Allison, Miss. Helen Loraine                     C22 C26        S  NaN    NaN
# Allison, Mr. Hudson Joshua Creighton             C22 C26        S  NaN  135.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  C22 C26        S  NaN    NaN
#
#                                                                        home.dest
# name
# Allen, Miss. Elisabeth Walton                                       St Louis, MO
# Allison, Master. Hudson Trevor                   Montreal, PQ / Chesterville, ON
# Allison, Miss. Helen Loraine                     Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton             Montreal, PQ / Chesterville, ON
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### 13.Grouping Rows by values

# %%
df.groupby('sex').mean()
# Out:
#           pclass  survived        age     sibsp     parch       fare     body
# sex
# female  2.154506  0.727468  28.687071  0.652361  0.633047  46.198097  166.625

# %% [markdown]
# ### 14. Grouping Rows by time

# %%
# Load libraries
import pandas as pd
import numpy as np

# %%
# Create date range
time_index = pd.date_range('11/10/2020', periods=100000, freq='30S')

# %%
# Create DataFrame
dataframe = pd.DataFrame(index=time_index)

# %%
# Create column of random values
dataframe['Sale_Amount'] = np.random.randint(1, 10, 100000)

# %%
# Group rows by week, calculate sum per week
dataframe.resample('W').sum()
# Out:
#             Sale_Amount
# 2020-11-15        86048
# 2020-11-22       100848
# 2020-11-29       100518
# 2020-12-06       101441
# 2020-12-13       101082
# 2020-12-20        10481

# %%
# Show three rows
dataframe.head(3)
# Out:
#                      Sale_Amount
# 2020-11-10 00:00:00            4
# 2020-11-10 00:00:30            9
# 2020-11-10 00:01:00            1

# %%
# Group by two weeks, calculate mean
dataframe.resample('2W').mean()
# Out:
#             Sale_Amount
# 2020-11-15     4.979630
# 2020-11-29     4.994196
# 2020-12-13     5.022892
# 2020-12-27     5.038942

# %%
# Group by month, count rows
dataframe.resample('M').count()
# Out:
#             Sale_Amount
# 2020-11-30        60480
# 2020-12-31        39520

# %%
# Group by month, count rows
dataframe.resample('M', label='left').count()
# Out:
#             Sale_Amount
# 2020-10-31        60480
# 2020-11-30        39520

# %% [markdown]
# ### 15. Looping Over a Column

# %%
# Print first two names uppercased
for name in df['name'][0:2]:
    print(name.upper())
# Out:
# ALLEN, MISS. ELISABETH WALTON
# ALLISON, MASTER. HUDSON TREVOR

# %% [markdown]
# ### 16.Applying a Function Over All Elements in a Column

# %%
# Create a dataframe from a list of dictionaries
rectangles = [
    { 'height': 40, 'width': 10 },
    { 'height': 20, 'width': 9 },
    { 'height': 3.4, 'width': 4 }
]

rectangles_df = pd.DataFrame(rectangles)
rectangles_df
# Out:
#    height  width
# 0    40.0     10
# 1    20.0      9
# 2     3.4      4

# %%
# Use the height and width to calculate the area
def calculate_area(row):
    return row['height'] * row['width']

rectangles_df.apply(calculate_area, axis=1)
# Out:
# 0    400.0
# 1    180.0
# 2     13.6
# dtype: float64

# %%
# Use .apply to save the new column if we'd like
rectangles_df['area'] = rectangles_df.apply(calculate_area, axis=1)
rectangles_df
# Out:
#    height  width   area
# 0    40.0     10  400.0
# 1    20.0      9  180.0
# 2     3.4      4   13.6

# %% [markdown]
# ### 17.Applying a Function to Groups

# %%
# Group rows, apply function to groups
df.groupby('sex').apply(lambda x: x.count())
# Out:
#         pclass  survived  name  sex  age  sibsp  parch  ticket  fare  cabin  \
# sex
# female     466       466   466  466  388    466    466     466   466    141
#
#         embarked  boat  body  home.dest
# sex
# female       464   319     8        288

# %% [markdown]
# ### 18.Concatenating DataFrames

# %%
# Create DataFrame
data_a = {'id': ['1', '2', '3'],
'first': ['Alex', 'Amy', 'Allen'],
'last': ['Anderson', 'Ackerman', 'Ali']}
dataframe_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])
# Create DataFrame
data_b = {'id': ['4', '5', '6'],
'first': ['Billy', 'Brian', 'Bran'],
'last': ['Bonder', 'Black', 'Balwner']}
dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

# %%
# Concatenate DataFrames by rows
pd.concat([dataframe_a, dataframe_b], axis=0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %% [markdown]
# ### 19.Merging DataFrames

# %%
# Create DataFrame
employee_data = {'employee_id': ['1', '2', '3', '4'],
'name': ['Amy Jones', 'Allen Keys', 'Alice Bees',
'Tim Horton']}
dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id',
'name'])
# Create DataFrame
sales_data = {'employee_id': ['3', '4', '5', '6'],
'total_sales': [23456, 2512, 2345, 1455]}
dataframe_sales = pd.DataFrame(sales_data, columns = ['employee_id',
'total_sales'])

# %%
# Merge DataFrames
pd.merge(dataframe_employees, dataframe_sales, on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512
